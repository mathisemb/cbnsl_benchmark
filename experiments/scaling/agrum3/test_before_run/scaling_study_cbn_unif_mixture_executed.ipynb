# %% [markdown]
# # Scaling study

# %%
import sys; sys.path.insert(0, "../../../..")
# %load_ext autoreload
# %autoreload 2

from functools import partial

from algorithms.CMIICAdapter import CMIICAdapter
from algorithms.CPCAdapter import CPCAdapter

from data.generators import generate_from_sem, generate_from_cbn_dag
from experiments.scaling.runner import ScalingRunner
from experiments.scaling.plot import plot_facet, METRIC_NAMES
from experiments.scaling.io import load_results

# %% [markdown]
# ## Configuration

# %%
algo_configs = [
    ("CPC",   CPCAdapter,   {"alpha": 0.05, "max_conditioning_set_size": 3}),
    ("CMIIC", CMIICAdapter, {"alpha": 0.05}),
]

generator = partial(generate_from_cbn_dag, marginal_type="Uniform", lcc_types="MixtureCopula")

runner = ScalingRunner(
    algo_configs=algo_configs,
    generator=generator,
    generator_name="cbn_unif_mixture",
    n_vars_list=[5, 10],
    n_samples_list=[200, 500],
    density=1.5,
    n_graphs=5,
    seed=42,
)

# test : resultats dans test_before_run/ au lieu de agrum3/
from pathlib import Path
runner.results_dir = Path("results_test") / runner.results_dir.name

# %% [markdown]
# ## Run

# %%
df = runner.run()
# Out:
# [2/40] CMIIC | v=5 a=8 s=200 g=0
# [6/40] CMIIC | v=5 a=8 s=200 g=1
# [10/40] CMIIC | v=5 a=8 s=200 g=2
# [14/40] CMIIC | v=5 a=8 s=200 g=3
# [18/40] CMIIC | v=5 a=8 s=200 g=4
# [20/40] CMIIC | v=5 a=8 s=500 g=4
# [22/40] CMIIC | v=10 a=15 s=200 g=0
# [24/40] CMIIC | v=10 a=15 s=500 g=0
# [26/40] CMIIC | v=10 a=15 s=200 g=1
# [28/40] CMIIC | v=10 a=15 s=500 g=1
# [30/40] CMIIC | v=10 a=15 s=200 g=2
# [32/40] CMIIC | v=10 a=15 s=500 g=2
# [34/40] CMIIC | v=10 a=15 s=200 g=3
# [36/40] CMIIC | v=10 a=15 s=500 g=3
# [38/40] CMIIC | v=10 a=15 s=200 g=4
# [40/40] CMIIC | v=10 a=15 s=500 g=4

# %% [markdown]
# ## (ou charger des résultats existants)

# %%
#df = load_results("results/2026-03-27_13h11_cbn_unif_mixture/results.csv")

# %% [markdown]
# ## Visualisation

# %%
plot_facet(df, y="time_s", col="n_vars"); # Temps de calcul

# %% [markdown]
# ## Métriques

# %% [markdown]
# ### Sur les CPDAG

# %%
for metric in METRIC_NAMES:
    plot_facet(df, y=metric, col="n_vars");

# %% [markdown]
# ### Sur les squelettes

# %%
for metric in METRIC_NAMES:
    plot_facet(df, y=f"{metric}_skeleton", col="n_vars");
