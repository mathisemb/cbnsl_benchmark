# %% [markdown]
# # Synthetic basic CBN dataset (non-Gaussian)
#
# - exponential marginals
# - Clayton local conditional copulas
# - 5 variables
# - 200 samples
#
# (comparison with the skeletons)

# %%
import sys; sys.path.insert(0, "../../../..")
import pyagrum as gum
from pipeline.Benchmark import Benchmark
 
dag = gum.DAG()
dag.addNodes(5)
for t, h in [(1,0),(1,2),(3,2),(3,4),(4,2)]:
    dag.addArc(t, h)

bench = Benchmark.synthetic_cbn_exp_clayton(dag, n_samples=200, seed=42, compare_mode="skeleton")

# %% [markdown]
# ## 1. Golden structure

# %%
bench.show_golden()

# %% [markdown]
# ## 2. Grid search

# %%
bench.run()

# %% [markdown]
# ## 3. Résultats par algorithme

# %%
bench.plot_grid_search()

# %% [markdown]
# ## 4. Meilleurs profils par algorithme

# %%
bench.plot_best_scores()

# %% [markdown]
# ## 5. Structures apprises (CPDAGs)

# %%
bench.plot_structures()

# %% [markdown]
# ## 6. Comparaisons pairwise

# %%
bench.plot_pairwise_heatmaps()

# %% [markdown]
# ---
#
# To html

# %%
# !jupyter nbconvert --to html "{__vsc_ipynb_file__}"
