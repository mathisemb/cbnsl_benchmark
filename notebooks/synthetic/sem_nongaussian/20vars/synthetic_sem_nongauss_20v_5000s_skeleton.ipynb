# %% [markdown]
# # Synthetic medium SEM dataset (non-Gaussian)
#
# - non-Gaussian linear SEM (uniform noise)
# - 20 variables
# - 5000 samples
#
# (comparison with the skeletons)

# %%
import sys; sys.path.insert(0, "../../../..")
import pyagrum as gum
from pipeline.Benchmark import Benchmark
 
dag = gum.DAG()
dag.addNodes(20)
for t, h in [(1,0),(0,2),(2,3),(1,3),(3,4),(4,5),(4,6),(5,7),(6,7),(6,8),(9,8),(2,9),(11,7),(0,15),
             (9,10),(12,10),(12,11),(16,15),(14,15),(16,14),(13,12),(14,13),(13,17),(16,17),(17,18),
             (18,19)]:
    dag.addArc(t, h)

bench = Benchmark.synthetic_nongausslinSEM(dag, n_samples=5000, seed=42, compare_mode="skeleton")

# %% [markdown]
# ## 1. Golden structure

# %%
bench.show_golden()

# %% [markdown]
# ## 2. Grid search

# %%
bench.run()

# %% [markdown]
# ## 3. Résultats par algorithme

# %%
bench.plot_grid_search()

# %% [markdown]
# ## 4. Meilleurs profils par algorithme

# %%
bench.plot_best_scores()

# %% [markdown]
# ## 5. Structures apprises (CPDAGs)

# %%
bench.plot_structures()

# %% [markdown]
# ## 6. Comparaisons pairwise

# %%
bench.plot_pairwise_heatmaps()

# %% [markdown]
# ---
#
# To html

# %%
# !jupyter nbconvert --to html "{__vsc_ipynb_file__}"
