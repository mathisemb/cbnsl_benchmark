# %% [markdown]
# # Benchmark on Synthetic CBN Data

# %%
import sys; sys.path.insert(0, "../..")
import pyagrum as gum
from pipeline.Benchmark import Benchmark
 
dag = gum.DAG()
dag.addNodes(4)
for t, h in [(0,1),(2,1),(2,3)]:
    dag.addArc(t, h)

bench = Benchmark.synthetic_cbn_unif_gauss(dag, n_samples=100, seed=42, copula_correlation=0.8)

# %% [markdown]
# ## 1. Golden structure

# %%
bench.show_golden()
# Out:
# Golden CPDAG: 2 arcs, 1 edges

# %% [markdown]
# ## 2. Grid search

# %%
bench.run()
# Out:
# Hartemink merging:   0%|          | 0/72 [00:00<?, ?it/s]
# Hartemink merging: 100%|██████████| 72/72 [00:00<00:00, 79.41it/s]
# Grid search: 100%|██████████| 348/348 [01:33<00:00,  3.71it/s, LiNGAM]
# Re-running best profiles (rank_by=F1-Score)...
# Hartemink merging: 100%|██████████| 72/72 [00:00<00:00, 132.17it/s]
# Done.
# Benchmark(dataset='synthetic_4nodes', 9 algorithms)

# %% [markdown]
# ## 3. Résultats par algorithme

# %%
bench.plot_grid_search()

# %% [markdown]
# ## 4. Meilleurs profils par algorithme

# %%
bench.plot_best_scores()

# %% [markdown]
# ## 5. Structures apprises (CPDAGs)

# %%
bench.plot_structures()
# Out:
# CPC v1 (alpha=0.05, max_conditioning_set_size=2) — 0 arcs, 1 edges
# CPC v2 (alpha=0.05, max_conditioning_set_size=2) — 0 arcs, 1 edges
# CMIIC v1 (alpha=0.05) — 0 arcs, 3 edges
# CMIIC v2 (alpha=0.01) — 3 arcs, 2 edges
# MIIC (n_bins=4, discretization_method=quantile) — 0 arcs, 1 edges
# GHC+BDeu (n_bins=2, discretization_method=hartemink, initial_bins=20) — 2 arcs, 1 edges
# NOTEARS (lambda1=0.0, w_threshold_notears=0.3) — 0 arcs, 3 edges
# NOTEARS Disc. (lambda1=0.0, w_threshold_notears=0.3, n_bins=4, discretization_method=quantile) — 0 arcs, 3 edges
# LiNGAM seed 0 (threshold_lingam=0.01) — 0 arcs, 4 edges

# %% [markdown]
# ## 6. Comparaisons pairwise

# %%
bench.plot_pairwise_heatmaps()
